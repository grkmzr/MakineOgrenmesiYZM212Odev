# %% [markdown]
# # HMM ile İzole Kelime Tanıma
# YZM212 Makine Öğrenmesi
#
# **Ad Soyad:** Görkem Özer
# **Okul No:** 23291007
#
# Bu çalışmada Hidden Markov Model (HMM) kullanılarak basit bir kelime tanıma sistemi simüle edilmiştir.

# %% [markdown]
# ## 1. Viterbi Hesabı
# Gözlem dizisi: **[High, Low]**
#
# Başlangıç: P(e)=1.0
#
# δ₁(e) = 1.0 × 0.7 = **0.7**
#
# t=2 için:
#
# e→e = 0.7 × 0.6 × 0.3 = **0.126**
#
# e→v = 0.7 × 0.4 × 0.9 = **0.252**
#
# En yüksek değer 0.252 olduğu için en olası fonem dizisi **e → v** olur.

# %% [markdown]
# ## 2. Python ile Basit Kelime Tanıyıcı

# %%
import numpy as np
from hmmlearn import hmm

# EV kelimesi için model
model_ev = hmm.MultinomialHMM(n_components=2, n_iter=100)

X_ev = np.array([[0],[1],[0],[1],[0]])
lengths_ev = [5]

model_ev.fit(X_ev, lengths_ev)

# OKUL kelimesi için model
model_okul = hmm.MultinomialHMM(n_components=3, n_iter=100)

X_okul = np.array([[1],[1],[0],[1],[0],[1]])
lengths_okul = [6]

model_okul.fit(X_okul, lengths_okul)

def kelime_tahmin(obs):
    obs = np.array(obs).reshape(-1,1)

    score_ev = model_ev.score(obs)
    score_okul = model_okul.score(obs)

    if score_ev > score_okul:
        return 'Tahmin edilen kelime: EV'
    else:
        return 'Tahmin edilen kelime: OKUL'

test = [0,1]

print(kelime_tahmin(test))

# %% [markdown]
# ## 3. Analiz
#
# **Gürültü etkisi:**
# Konuşma verisinde gürültü olduğunda gözlem değerleri gerçek fonemi tam temsil etmeyebilir. Bu durum emisyon olasılıklarının dağılımını etkileyebilir ve modelin yanlış tahmin yapmasına neden olabilir.
#
# **Deep Learning neden kullanılıyor:**
# Kelime sayısı çok arttığında HMM modelleri yetersiz kalabilir. Derin öğrenme yöntemleri büyük veri ile daha iyi özellik öğrenebildiği için modern konuşma tanıma sistemlerinde daha çok tercih edilmektedir.
